# %%
import matplotlib
# %matplotlib inline
import random as rd
import numpy as np

import networkx as nx
g = nx.erdos_renyi_graph(30, 0.05, directed = True, seed = 123)
nx.draw(g, pos=nx.kamada_kawai_layout(g))

# %%
print ('PAGE RANK', nx.pagerank(g))

alpha = 0.85
N = 1000000
nodes_list = list(g.nodes())
surfer = rd.choice(nodes_list)
print ('surfer',surfer)
#print (nodes_list)

count_list = [0 for node in nodes_list]

# start surfer on random node
for _ in range(N):
    neighbors = list(g.neighbors(surfer))
#     if rd.random() < alpha:
#         if len(neighbors) > 0:
#             surfer = rd.choice(neighbors)
#         else:
#             surfer = rd.choice(nodes_list)
#     else:
#         surfer = rd.choice(nodes_list)
    if (len(neighbors) == 0) or (rd.uniform(0, 1) > alpha):
        surfer = rd.choice(list(g.nodes))
    else:
        surfer = rd.choice(neighbors)
        
    count_list[surfer] +=1
    ys.append(count_list)

#get the end result
sum_count = sum(count_list)
for i in range(len(count_list)):
    count_list[i] = count_list[i]/float(N)
    
# #get the ys result
# for i in range(N):
#     #subtract all of them
#     ys[i] = np.mean(ys[i])/float(i)
    

print ('COUNT LIST',count_list)
# Out:
# PAGE RANK {0: 0.01321914850756847, 1: 0.04305614905051307, 2: 0.0224184422385673, 3: 0.020763573555365067, 4: 0.1519409000092644, 5: 0.015278038556628357, 6: 0.04357199076624549, 7: 0.08868962006965002, 8: 0.009276594051426114, 9: 0.027215223573378695, 10: 0.009276594051426114, 11: 0.009276594051426114, 12: 0.009276594051426114, 13: 0.021104257419853185, 14: 0.023535500084085954, 15: 0.009276594051426114, 16: 0.018135203917936826, 17: 0.009276594051426114, 18: 0.01264966891920012, 19: 0.05375946044542632, 20: 0.009276594051426114, 21: 0.011904963688854351, 22: 0.15057445865003966, 23: 0.02084377195458973, 24: 0.025679331302227965, 25: 0.02721686924658904, 26: 0.0925438315518033, 27: 0.009276594051426114, 28: 0.009276594051426114, 29: 0.03241025002937753}
# surfer 25
# ...

# %%
alpha 
if random node in neighbors > 0
random node
else  random total

if (1-alpha) or 0

else

# %%
print (rd.choice(nodes_list))
# Out:
# 26

# %%
xs = list(range(N))
ys = []
